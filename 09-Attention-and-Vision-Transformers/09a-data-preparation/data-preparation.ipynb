# %% [markdown]
# ---
# # CIFAR-10 Preparations for Vision Transformers
# ---
# In this notebook, you will load and prepare the CIFAR-10 dataset for ViT training and implement image patch extraction.

# %% [markdown]
# ---
# # Imports
# ---
#
# Run the code cell below after you have set up everything correctly (either locally or in Colab).

# %%
import data
import tests
import visual
import patchify
import importlib

# %% [markdown]
# ---
# ## Data Loading
# ---
#
# Create a `train_loader` and a `test_loader` for CIFAR-10 dataset and apply some data transformations to prepare the data for training.
#
# ## **Task:**
#
# Implement the `make_cifar10_loaders` function in `data.py`.
#
# **Hints:**
# - Define two separate transform pipelines `train_transform` and `test_transform`.
# - Use the functions `ToImage`, `ToDtype` and `Normalize` from the `torchvision.transforms.v2` package in both pipelines.
# - Normalization: Use the mean and std given in `data.py`.
# - Add `transforms.RandomCrop(32, padding=4)` and `transforms.RandomHorizontalFlip()` at the beginning of your `train_transform` pipeline.
# - Use `torchvision.transforms.v2.Compose` for combining multiple tranformations to execute them sequentially.
# - Use `torchvision.datasets.CIFAR10` to create the dataset objects and pass your transformation pipelines (Compose) as the `transform` argument.
# - Pass your datasets to `torch.utils.data.DataLoader` objects and ensure correct shuffling behavior.
#
# Run the code cell below.

# %%
importlib.reload(data)
tests.test_data_loaders()
# Out:
# PASS: make_cifar10_loaders transformation pipelines are correct.
# PASS: make_cifar10_loaders outputs and loader settings are correct.

# %% [markdown]
# ---
# ##  ViT Paper Reading
# ---
#
# ## **Task:**
#
# Read and understand the [Vision Transformer](https://arxiv.org/pdf/2010.11929) paper.
#
# Focus on the description of the Model architecture, since you will be implementing it yourself.

# %% [markdown]
# ---
# ##  Patchify
# ---
#
# Convert a batch of images into a sequence of flattened, non-overlapping patches. Try starting with a loop-based implementation and see if you can find a fully vectorized one.
#
# ## **Task:**
#
# Implement the function `create_patch_sequence` in `patchify.py`.
#
#
# **Hints:**
# - Make sure the function works for any image size that is divisible by the patch size.
# - Keep the batch dimension unchanged.
# - Vectorization: Consider `torch.unfold`, `torch.permute`, `torch.reshape` and `tensor.size`.
#
# Run the code cell below.

# %%
importlib.reload(patchify)
tests.test_patchify()
# Out:
# PASS: create_patch_sequence handles batched RGB inputs correctly.
# PASS: create_patch_sequence shape and patch content are correct.
# PASS: create_patch_sequence rejects non-divisible patch sizes.

# %% [markdown]
# ---
# # Patchify Visualization
# ---
#
# Run the cell below to visualize your extracted patches for a random CIFAR-10 Image. If your implementation works correctly, you should see 64 patches of size 4x4 that make up the original image. Feel free to rerun this cell a couple of times to see different examples.

# %%
visual.visualize_patches()
# Out:
# 100%|██████████| 170M/170M [28:01<00:00, 101kB/s]
