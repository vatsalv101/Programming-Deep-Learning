# %% [markdown]
# ---
# #  Multi Layer Perceptrons with PyTorch (3 Hours)
# ---
# Author: _Niklas Strahmann_, Marc Höftmann
#
# In this notebook, you will use high level PyTorch programming to implement a simple neural network (MLP) to classify handwritten digits.

# %%
# %load_ext autoreload
# %autoreload 2
import mlp
import visual
import torch

# %% [markdown]
# ---
# ## MNIST Dataset
# ---
# We want to classify images of handwritten digits (MNIST dataset). These 2D images have shape $28 \times 28$ and we treat the pixels as vectors of size $28*28=784$. Look at some of the images.

# %%
visual.mnist_pictures(n=2).show()

# %% [markdown]
#  To classify the images, we will use a fully connected neural network consisting of two linear layers.
#
# ## **Task:**
#
# Implement the class `SimpleMLP` in `mlp.py` by completing the following steps:
#
# 1. Initialize the neural network and its layers in `__init__`.
# 2. Implement `SimpleMLP.forward`, which takes a batch of images and returns the logits (=values before softmax) of the network.
# 3. Complete `SimpleMLP.predict_class` to give the class prediction for each image.
#
# Hints:
# - Use `nn.Linear` for a fully-connected layer. Use an `nn.Sequential` wrapper to combine all layers **including activations functions**.
# - Have a look at activation function layers: [Activation Functions](https://docs.pytorch.org/docs/stable/nn.html#non-linear-activations-weighted-sum-nonlinearity). Be careful where you put activation function layers!
# - In `forward`, call your network, which was initialized in `__init__`, and pass it the images.
# - To calculate class predictions, use `torch.argmax`. Apply it on `torch.softmax` output or on the logits (preferable).
#
# If you have completed the network, try to run a forward pass here:

# %%
net = mlp.SimpleMLP(dim_in = 5, dim_hidden = 10, dim_out = 3)
test_input = torch.randn(8, 5)
test_output = net(test_input)
test_class_predictions = net.predict_class(test_input)

# %% [markdown]
# ---
# ## Training Loop
# ---
#
#
# ## **Task:**
#
# Implement `train` in `mlp.py`. You need to do the following:
#
# 1. Initialize `SimpleMLP`, create the loss function `nn.CrossEntropyLoss` and create an optimizer `torch.optim.SGD`.
# 2. Inside the loop:
#     1. Perform `forward` using `SimpleMLP`.
#     2. Calculate the `loss`.
#     3. Reset the parameter gradients with `optimizer.zero_grad()`.
#     4. Perform a backward pass with `loss.backward()`.
#     5. Update the weights with `optimizer.step()`.
#
# If you have completed the steps, try to find good parameters for learning rate and batch size.
#
# Your chosen parameters should not need more than the default value of 10 epochs to reach $95\%$ test accuracy.

# %%
#####
# TODO
batch_size = 64
learning_rate = .01
######

net, h0, h1 = mlp.train(batch_size=batch_size, lr=learning_rate)
visual.show_training_stats(h0, h1)
# Out:
# Train error: 1.587, Test accuracy: 44.417 % correct:  20%|██        | 2/10 [00:26<01:45, 13.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       3 batch_size = 64
#       4 learning_rate = .01
#       5 ######
#       6
# ----> 7 net, h0, h1 = mlp.train(batch_size=batch_size, lr=learning_rate)
#       8 visual.show_training_stats(h0, h1)
#
# File d:\Deep Learning\exercises\02-exercises\02c-mlp-high-level\mlp.py:28, in train(lr, batch_size, epochs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File d:\Deep Learning\.venv\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# ...

# %% [markdown]
# You can see how your network performs here on some of the test images:

# %%
visual.mnist_predictions(net, n=4).show()
